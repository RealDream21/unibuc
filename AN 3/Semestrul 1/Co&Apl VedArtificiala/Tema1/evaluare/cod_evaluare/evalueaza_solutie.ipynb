# %%
def compare_annotations_position_token(filename_predicted,filename_gt,verbose=0):
	p = open(filename_predicted,"rt")  	
	gt = open(filename_gt,"rt") 

	
	line_gt = gt.readline()
	current_pos_gt, current_token_gt = line_gt.split()
	if verbose:
		print(current_pos_gt,current_token_gt)
	
	line_p = p.readline()
	current_pos_p, current_token_p = line_p.split()
	if verbose:
		print(current_pos_p,current_token_p)

	
	match_positions = 1
	match_tokens = 1
	if(current_pos_p != current_pos_gt):
		match_positions = 0
	if(current_token_p != current_token_gt):
		match_tokens = 0
	

	points_positions = 0.025 * match_positions
	points_tokens = 0.01 * match_tokens	


	return points_positions, points_tokens

#change this on your machine pointing to your results (txt files)
predictions_path_root = "../fisiere_solutie/334_Florete_FabianAndrei/"

#change this on your machine to point to the ground-truth test
gt_path_root = "fake_test_gt/"



def compare_annotations_score(filename_predicted,filename_gt,verbose=0):
	p = open(filename_predicted,"rt")  	
	gt = open(filename_gt,"rt") 

	all_lines_gt = gt.readlines()
	all_lines_p = p.readlines()


	number_lines_gt = len(all_lines_gt)

	points_scores = 0

	try:
		for i in range(0,number_lines_gt):
			line_gt = all_lines_gt[i]
			line_p = all_lines_p[i]
			if (line_gt==line_p):
				points_scores += 0.04
	except:
		pass

	return points_scores


#change this to 1 if you want to print results at each turn
verbose = 1
total_points = 0
for game in range(1,5):
# change this for game in range(1,5):
	points_score = 0
	for turn in range(1,51):
		
		name_turn = str(turn)
		if(turn < 10):
			name_turn = '0'+str(turn)

		filename_predicted = predictions_path_root + str(game) + '_' + name_turn + '.txt'
		filename_gt = gt_path_root + str(game) + '_' + name_turn + '.txt'

		game_turn = str(game) + '_' + name_turn
		points_position = 0
		points_tokens = 0	

		try:
			points_position, points_tokens  = compare_annotations_position_token(filename_predicted,filename_gt,verbose)
		except:
			print("Pentru imaginea: ", game_turn, " functia de evaluare a intampinat o eroare")

		print("Imaginea: ", game_turn, "Puncte task 1: ", points_position, "Puncte task 2: ",points_tokens)
		
		total_points = total_points + points_position + points_tokens

	filename_predicted_scores = predictions_path_root + str(game) + '_scores' + '.txt'
	filename_gt_scores = gt_path_root + str(game) + '_scores' + '.txt'
	points_score = compare_annotations_score(filename_predicted_scores,filename_gt_scores,verbose=0)
	print("Puncte task 3 ", points_score)

	total_points = total_points + points_score
	print("Total puncte = ", total_points)


print(total_points)
# Out:
# 9G 2
# 9G 2
# Imaginea:  1_01 Puncte task 1:  0.025 Puncte task 2:  0.01
# 9H 6
# 9H 6
# Imaginea:  1_02 Puncte task 1:  0.025 Puncte task 2:  0.01
# 8I 7
# 8I 7
# Imaginea:  1_03 Puncte task 1:  0.025 Puncte task 2:  0.01
# 7I 1
# 7I 1
# Imaginea:  1_04 Puncte task 1:  0.025 Puncte task 2:  0.01
# 9I 8
# 9I 8
# Imaginea:  1_05 Puncte task 1:  0.025 Puncte task 2:  0.01
# 10I 15
# 10I 15
# Imaginea:  1_06 Puncte task 1:  0.025 Puncte task 2:  0.01
# 9J 14
# 9J 14
# Imaginea:  1_07 Puncte task 1:  0.025 Puncte task 2:  0.01
# 8J 11
# 8J 1
# Imaginea:  1_08 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7J 2
# 7J 2
# Imaginea:  1_09 Puncte task 1:  0.025 Puncte task 2:  0.01
# 
Puncte task 1:  0.025 Puncte task 2:  0.01
# 5G 4
# 5G 4
# Imaginea:  4_14 Puncte task 1:  0.025 Puncte task 2:  0.01
# 4G 8
# 4G 8
# Imaginea:  4_15 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6H 8
# 6H 8
# Imaginea:  4_16 Puncte task 1:  0.025 Puncte task 2:  0.01
# 8F 7
# 8F 7
# Imaginea:  4_17 Puncte task 1:  0.025 Puncte task 2:  0.01
# 7F 17
# 7F 17
# Imaginea:  4_18 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6F 2
# 6F 2
# Imaginea:  4_19 Puncte task 1:  0.025 Puncte task 2:  0.01
# 5F 19
# 5F 19
# Imaginea:  4_20 Puncte task 1:  0.025 Puncte task 2:  0.01
# 5H 10
# 5H 10
# Imaginea:  4_21 Puncte task 1:  0.025 Puncte task 2:  0.01
# 5I 14
# 5I 14
# Imaginea:  4_22 Puncte task 1:  0.025 Puncte task 2:  0.01
# 4I 16
# 4I 16
# Imaginea:  4_23 Puncte task 1:  0.025 Puncte task 2:  0.01
# 4H 80
# 4H 80
# Imaginea:  4_24 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3I 2
# 3I 2
# Imaginea:  4_25 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6J 4
# 6J 4
# Imaginea:  4_26 Puncte task 1:  0.025 Puncte task 2:  0.01
# 5J 4
# 5J 4
# Imaginea:  4_27 Puncte task 1:  0.025 Puncte task 2:  0.01
# 4J 1
# 4J 1
# Imaginea:  4_28 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3J 3
# 3J 3
# Imaginea:  4_29 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3H 1
# 3H 1
# Imaginea:  4_30 Puncte task 1:  0.025 Puncte task 2:  0.01
# 2H 81
# 2H 81
# Imaginea:  4_31 Puncte task 1:  0.025 Puncte task 2:  0.01
# 2J 3
# 2J 3
# Imaginea:  4_32 Puncte task 1:  0.025 Puncte task 2:  0.01
# 2I 18
# 2I 18
# Imaginea:  4_33 Puncte task 1:  0.025 Puncte task 2:  0.01
# 2K 21
# 2K 21
# Imaginea:  4_34 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3K 6
# 3K 6
# Imaginea:  4_35 Puncte task 1:  0.025 Puncte task 2:  0.01
# 4K 15
# 4K 15
# Imaginea:  4_36 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3L 9
# 3L 9
# Imaginea:  4_37 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3M 54
# 3M 54
# Imaginea:  4_38 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6K 6
# 6K 6
# Imaginea:  4_39 Puncte task 1:  0.025 Puncte task 2:  0.01
# 5K 10
# 5K 10
# Imaginea:  4_40 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6L 2
# 6L 2
# Imaginea:  4_41 Puncte task 1:  0.025 Puncte task 2:  0.01
# 3N 45
# 3N 45
# Imaginea:  4_42 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6M 8
# 6M 8
# Imaginea:  4_43 Puncte task 1:  0.025 Puncte task 2:  0.01
# 6N 10
# 6N 10
# Imaginea:  4_44 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1K 27
# 1K 27
# Imaginea:  4_45 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1J 9
# 1J 9
# Imaginea:  4_46 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1I 36
# 1I 36
# Imaginea:  4_47 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1L 3
# 1L 3
# Imaginea:  4_48 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1M 30
# 1M 30
# Imaginea:  4_49 Puncte task 1:  0.025 Puncte task 2:  0.01
# 1N 1
# 7L 1
# Imaginea:  4_50 Puncte task 1:  0.0 Puncte task 2:  0.01
# Puncte task 3  0.43999999999999995
# Total puncte =  8.804999999999996
# 8.804999999999996
