# %%
def compare_annotations_position_token(filename_predicted,filename_gt,verbose=0):
	p = open(filename_predicted,"rt")  	
	gt = open(filename_gt,"rt") 

	
	line_gt = gt.readline()
	current_pos_gt, current_token_gt = line_gt.split()
	if verbose:
		print(current_pos_gt,current_token_gt)
	
	line_p = p.readline()
	current_pos_p, current_token_p = line_p.split()
	if verbose:
		print(current_pos_p,current_token_p)

	
	match_positions = 1
	match_tokens = 1
	if(current_pos_p != current_pos_gt):
		match_positions = 0
	if(current_token_p != current_token_gt):
		match_tokens = 0
	

	points_positions = 0.025 * match_positions
	points_tokens = 0.01 * match_tokens	


	return points_positions, points_tokens

#change this on your machine pointing to your results (txt files)
predictions_path_root = "../fisiere_solutie/334_Florete_FabianAndrei/"

#change this on your machine to point to the ground-truth test
gt_path_root = "fake_test_gt/"



def compare_annotations_score(filename_predicted,filename_gt,verbose=0):
	p = open(filename_predicted,"rt")  	
	gt = open(filename_gt,"rt") 

	all_lines_gt = gt.readlines()
	all_lines_p = p.readlines()


	number_lines_gt = len(all_lines_gt)

	points_scores = 0

	try:
		for i in range(0,number_lines_gt):
			line_gt = all_lines_gt[i]
			line_p = all_lines_p[i]
			if (line_gt==line_p):
				points_scores += 0.04
	except:
		pass

	return points_scores


#change this to 1 if you want to print results at each turn
verbose = 1
total_points = 0
for game in range(1,5):
# change this for game in range(1,5):
	points_score = 0
	for turn in range(1,51):
		
		name_turn = str(turn)
		if(turn < 10):
			name_turn = '0'+str(turn)

		filename_predicted = predictions_path_root + str(game) + '_' + name_turn + '.txt'
		filename_gt = gt_path_root + str(game) + '_' + name_turn + '.txt'

		game_turn = str(game) + '_' + name_turn
		points_position = 0
		points_tokens = 0	

		try:
			points_position, points_tokens  = compare_annotations_position_token(filename_predicted,filename_gt,verbose)
		except:
			print("Pentru imaginea: ", game_turn, " functia de evaluare a intampinat o eroare")

		print("Imaginea: ", game_turn, "Puncte task 1: ", points_position, "Puncte task 2: ",points_tokens)
		
		total_points = total_points + points_position + points_tokens

	filename_predicted_scores = predictions_path_root + str(game) + '_scores' + '.txt'
	filename_gt_scores = gt_path_root + str(game) + '_scores' + '.txt'
	points_score = compare_annotations_score(filename_predicted_scores,filename_gt_scores,verbose=0)
	print("Puncte task 3 ", points_score)

	total_points = total_points + points_score
	print("Total puncte = ", total_points)


print(total_points)
# Out:
# 9H 8
# 9H 0
# Imaginea:  1_01 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10H 32
# 10H 0
# Imaginea:  1_02 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11H 40
# 11H 0
# Imaginea:  1_03 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12H 72
# 12H 0
# Imaginea:  1_04 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6H 8
# 6H 0
# Imaginea:  1_05 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5H 10
# 5H 0
# Imaginea:  1_06 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4H 80
# 4H 0
# Imaginea:  1_07 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3H 8
# 3H 0
# Imaginea:  1_08 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2H 10
# 2H 0
# Imaginea:  1_09 Puncte task 1:  0.025 Puncte task 2:  0.0
# 1H 18
# 1H 0
# Imaginea:  1_10 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6G 3
# 6G 0
# Imaginea:  1_11 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6F 11
# 6F 0
# Imaginea:  1_12 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6E 14
# 6E 0
# Imaginea:  1_13 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6I 5
# 6I 0
# Imaginea:  1_14 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6J 3
# 6J 0
# Imaginea:  1_15 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6K 15
# 6K 0
# Imaginea:  1_16 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6L 12
# 6L 0
# Imaginea:  1_17 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7I 3
# 7I 0
# Imaginea:  1_18 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8I 7
# 8I 0
# Imaginea:  1_19 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7J 6
# 7J 0
# Imaginea:  1_20 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5J 9
# 5J 0
# Imaginea:  1_21 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7K 9
# 7K 0
# Imaginea:  1_22 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7L 3
# 7L 0
# Imaginea:  1_23 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6D 3
# 6D 0
# Imaginea:  1_24 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9I 10
# 9I 0
# Imaginea:  1_25 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10I 17
# 10I 0
# Imaginea:  1_26 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10J 49
# 10J 0
# Imaginea:  1_27 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8J 9
# 8J 0
# Imaginea:  1_28 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8K 63
# 8K 0
# Imaginea:  1_29 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9K 54
# 9K 0
# Imaginea:  1_30 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5L 36
# 5L 0
# Imaginea:  1_31 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4L 48
# 4L 0
# Imaginea:  1_32 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6M 27
# 6M 0
# Imaginea:  1_33 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4J 6
# 4J 0
# Imaginea:  1_34 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8F 7
# 8F 0
# Imaginea:  1_35 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3J 3
# 3J 0
# Imaginea:  1_36 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2J 2
# 2J 0
# Imaginea:  1_37 Puncte task 1:  0.025 Puncte task 2:  0.0
# 1J 5
# 1J 0
# Imaginea:  1_38 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11I 7
# 11I 0
# Imaginea:  1_39 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12I 10
# 12I 0
# Imaginea:  1_40 Puncte task 1:  0.025 Puncte task 2:  0.0
# 13I 70
# 13I 0
# Imaginea:  1_41 Puncte task 1:  0.025 Puncte task 2:  0.0
# 14I 60
# 14I 0
# Imaginea:  1_42 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9G 2
# 9G 0
# Imaginea:  1_43 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10G 5
# 10G 0
# Imaginea:  1_44 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9F 10
# 9F 0
# Imaginea:  1_45 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10F 3
# 10F 0
# Imaginea:  1_46 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10E 8
# 10E 0
# Imaginea:  1_47 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10D 5
# 10D 0
# Imaginea:  1_48 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9E 8
# 9E 0
# Imaginea:  1_49 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11E 0
# 11E 0
# Imaginea:  1_50 Puncte task 1:  0.025 Puncte task 2:  0.01
# Puncte task 3  0
# Total puncte =  1.2599999999999996
# 7I 3
# 7I 0
# Imaginea:  2_01 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7J 6
# 7J 0
# Imaginea:  2_02 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7K 9
# 7K 0
# Imaginea:  2_03 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7L 15
# 7L 0
# Imaginea:  2_04 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7M 6
# 7M 0
# Imaginea:  2_05 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7N 90
# 7N 0
# Imaginea:  2_06 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7F 3
# 7F 0
# Imaginea:  2_07 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8I 7
# 8I 0
# Imaginea:  2_08 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9I 21
# 9I 0
# Imaginea:  2_09 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9H 6
# 9H 0
# Imaginea:  2_10 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9G 27
# 9G 0
# Imaginea:  2_11 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10G 30
# 10G 0
# Imaginea:  2_12 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10H 24
# 10H 0
# Imaginea:  2_13 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10I 54
# 10I 0
# Imaginea:  2_14 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10F 6
# 10F 0
# Imaginea:  2_15 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6H 6
# 6H 0
# Imaginea:  2_16 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6G 4
# 6G 0
# Imaginea:  2_17 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6F 2
# 6F 0
# Imaginea:  2_18 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8F 5
# 8F 0
# Imaginea:  2_19 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9F 8
# 9F 0
# Imaginea:  2_20 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9E 35
# 9E 0
# Imaginea:  2_21 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7E 4
# 7E 0
# Imaginea:  2_22 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6I 10
# 6I 0
# Imaginea:  2_23 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5H 8
# 5H 0
# Imaginea:  2_24 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4H 48
# 4H 0
# Imaginea:  2_25 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3H 40
# 3H 0
# Imaginea:  2_26 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2H 8
# 2H 0
# Imaginea:  2_27 Puncte task 1:  0.025 Puncte task 2:  0.0
# 1H 32
# 1H 0
# Imaginea:  2_28 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6E 6
# 6E 0
# Imaginea:  2_29 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7D 12
# 7D 0
# Imaginea:  2_30 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7C 16
# 7C 0
# Imaginea:  2_31 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7B 28
# 7B 0
# Imaginea:  2_32 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5F 5
# 5F 0
# Imaginea:  2_33 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5E 2
# 5E 0
# Imaginea:  2_34 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5G 10
# 5G 0
# Imaginea:  2_35 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4G 14
# 4G 0
# Imaginea:  2_36 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3G 4
# 3G 0
# Imaginea:  2_37 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2G 18
# 2G 0
# Imaginea:  2_38 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2I 10
# 2I 0
# Imaginea:  2_39 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3I 36
# 3I 0
# Imaginea:  2_40 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6J 4
# 6J 0
# Imaginea:  2_41 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3J 4
# 3J 0
# Imaginea:  2_42 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8J 10
# 8J 0
# Imaginea:  2_43 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8K 70
# 8K 0
# Imaginea:  2_44 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5I 2
# 5I 0
# Imaginea:  2_45 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5J 10
# 5J 0
# Imaginea:  2_46 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5K 8
# 5K 0
# Imaginea:  2_47 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11F 2
# 11F 0
# Imaginea:  2_48 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12F 4
# 12F 0
# Imaginea:  2_49 Puncte task 1:  0.025 Puncte task 2:  0.0
# 13F 2
# 13F 0
# Imaginea:  2_50 Puncte task 1:  0.025 Puncte task 2:  0.0
# Puncte task 3  0
# Total puncte =  2.5099999999999953
# 7I 1
# 7I 0
# Imaginea:  3_01 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8I 1
# 8I 0
# Imaginea:  3_02 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6I 0
# 6I 0
# Imaginea:  3_03 Puncte task 1:  0.025 Puncte task 2:  0.01
# 8J 5
# 8J 0
# Imaginea:  3_04 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7J 2
# 7J 0
# Imaginea:  3_05 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7K 3
# 7K 0
# Imaginea:  3_06 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8K 5
# 8K 0
# Imaginea:  3_07 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6K 8
# 6K 0
# Imaginea:  3_08 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6J 10
# 6J 0
# Imaginea:  3_09 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5J 8
# 5J 0
# Imaginea:  3_10 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4J 80
# 4J 0
# Imaginea:  3_11 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5I 1
# 5I 0
# Imaginea:  3_12 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4I 1
# 4I 0
# Imaginea:  3_13 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4K 81
# 4K 0
# Imaginea:  3_14 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3J 10
# 3J 0
# Imaginea:  3_15 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7F 3
# 7F 0
# Imaginea:  3_16 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7E 4
# 7E 0
# Imaginea:  3_17 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7D 12
# 7D 0
# Imaginea:  3_18 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6H 6
# 6H 0
# Imaginea:  3_19 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5H 8
# 5H 0
# Imaginea:  3_20 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4H 48
# 4H 0
# Imaginea:  3_21 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4G 49
# 4G 0
# Imaginea:  3_22 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4F 1
# 4F 0
# Imaginea:  3_23 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8F 7
# 8F 0
# Imaginea:  3_24 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9F 10
# 9F 0
# Imaginea:  3_25 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10F 17
# 10F 0
# Imaginea:  3_26 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9H 2
# 9H 0
# Imaginea:  3_27 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10H 8
# 10H 0
# Imaginea:  3_28 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11H 10
# 11H 0
# Imaginea:  3_29 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12H 2
# 12H 0
# Imaginea:  3_30 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9I 2
# 9I 0
# Imaginea:  3_31 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10I 3
# 10I 0
# Imaginea:  3_32 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10G 11
# 10G 0
# Imaginea:  3_33 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10E 28
# 10E 0
# Imaginea:  3_34 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11F 7
# 11F 0
# Imaginea:  3_35 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10D 45
# 10D 0
# Imaginea:  3_36 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12F 10
# 12F 0
# Imaginea:  3_37 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6F 10
# 6F 0
# Imaginea:  3_38 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6G 4
# 6G 0
# Imaginea:  3_39 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8E 21
# 8E 0
# Imaginea:  3_40 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6E 25
# 6E 0
# Imaginea:  3_41 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6D 35
# 6D 0
# Imaginea:  3_42 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6C 10
# 6C 0
# Imaginea:  3_43 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7C 16
# 7C 0
# Imaginea:  3_44 Puncte task 1:  0.025 Puncte task 2:  0.0
# 13F 3
# 13F 0
# Imaginea:  3_45 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7B 4
# 7B 0
# Imaginea:  3_46 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7A 20
# 7A 0
# Imaginea:  3_47 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5C 6
# 5C 0
# Imaginea:  3_48 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11I 5
# 11I 0
# Imaginea:  3_49 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11J 50
# 11J 0
# Imaginea:  3_50 Puncte task 1:  0.025 Puncte task 2:  0.0
# Puncte task 3  0
# Total puncte =  3.7699999999999907
# 7I 3
# 7I 0
# Imaginea:  4_01 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7J 6
# 7J 0
# Imaginea:  4_02 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6H 6
# 6H 0
# Imaginea:  4_03 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5H 8
# 5H 0
# Imaginea:  4_04 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9G 4
# 9G 0
# Imaginea:  4_05 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8I 1
# 8I 0
# Imaginea:  4_06 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8J 5
# 8J 0
# Imaginea:  4_07 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7K 9
# 7K 0
# Imaginea:  4_08 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8K 5
# 8K 0
# Imaginea:  4_09 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4H 48
# 4H 0
# Imaginea:  4_10 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3H 40
# 3H 0
# Imaginea:  4_11 Puncte task 1:  0.025 Puncte task 2:  0.0
# 2H 8
# 2H 0
# Imaginea:  4_12 Puncte task 1:  0.025 Puncte task 2:  0.0
# 1H 32
# 1H 0
# Imaginea:  4_13 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10G 7
# 10G 0
# Imaginea:  4_14 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11G 28
# 11G 0
# Imaginea:  4_15 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12G 21
# 12G 0
# Imaginea:  4_16 Puncte task 1:  0.025 Puncte task 2:  0.0
# 13G 7
# 13G 0
# Imaginea:  4_17 Puncte task 1:  0.025 Puncte task 2:  0.0
# 14G 3
# 14G 0
# Imaginea:  4_18 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9H 6
# 9H 0
# Imaginea:  4_19 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10H 24
# 10H 0
# Imaginea:  4_20 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11H 30
# 11H 0
# Imaginea:  4_21 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12H 54
# 12H 0
# Imaginea:  4_22 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9K 45
# 9K 0
# Imaginea:  4_23 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8L 25
# 8L 0
# Imaginea:  4_24 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8M 5
# 8M 0
# Imaginea:  4_25 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8N 5
# 8N 0
# Imaginea:  4_26 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7L 3
# 7L 0
# Imaginea:  4_27 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7M 12
# 7M 0
# Imaginea:  4_28 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7N 15
# 7N 0
# Imaginea:  4_29 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9J 1
# 9J 0
# Imaginea:  4_30 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10J 6
# 10J 0
# Imaginea:  4_31 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6J 11
# 6J 0
# Imaginea:  4_32 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5J 5
# 5J 0
# Imaginea:  4_33 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4J 16
# 4J 0
# Imaginea:  4_34 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10F 17
# 10F 0
# Imaginea:  4_35 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10E 10
# 10E 0
# Imaginea:  4_36 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9F 10
# 9F 0
# Imaginea:  4_37 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8F 7
# 8F 0
# Imaginea:  4_38 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7F 3
# 7F 0
# Imaginea:  4_39 Puncte task 1:  0.025 Puncte task 2:  0.0
# 7E 4
# 7E 0
# Imaginea:  4_40 Puncte task 1:  0.025 Puncte task 2:  0.0
# 9E 6
# 9E 0
# Imaginea:  4_41 Puncte task 1:  0.025 Puncte task 2:  0.0
# 8E 60
# 8E 0
# Imaginea:  4_42 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11E 4
# 11E 0
# Imaginea:  4_43 Puncte task 1:  0.025 Puncte task 2:  0.0
# 11J 7
# 11J 0
# Imaginea:  4_44 Puncte task 1:  0.025 Puncte task 2:  0.0
# 10D 7
# 10D 0
# Imaginea:  4_45 Puncte task 1:  0.025 Puncte task 2:  0.0
# 12E 14
# 12E 0
# Imaginea:  4_46 Puncte task 1:  0.025 Puncte task 2:  0.0
# 6F 10
# 6F 0
# Imaginea:  4_47 Puncte task 1:  0.025 Puncte task 2:  0.0
# 5F 13
# 5F 0
# Imaginea:  4_48 Puncte task 1:  0.025 Puncte task 2:  0.0
# 4F 3
# 4F 0
# Imaginea:  4_49 Puncte task 1:  0.025 Puncte task 2:  0.0
# 3F 10
# 3F 0
# Imaginea:  4_50 Puncte task 1:  0.025 Puncte task 2:  0.0
# Puncte task 3  0
# Total puncte =  5.020000000000004
# 5.020000000000004
