# %%
# !set CUDA_VISIBLE_DEVICES=""

# %%
import pandas as pd
import sklearn
import os
import torch
import matplotlib.pyplot as plt
os.environ["KERAS_BACKEND"] = 'torch'
os.environ["CUDA_VISIBLE_DEVICES"] = "" 
import keras

# %%
torch.backends.cudnn.enabled = False
torch.cuda.is_available = lambda: False
torch.device("cpu")
# Out:
# device(type='cpu')

# %%
torch.cuda.is_available()
# Out:
# False

# %%
df = pd.read_csv('pmi-data.csv')

# %%
# %%html
# <h1>1. Datasets and Dataloaders</h1>
# Out:
# <h1>1. Datasets and Dataloaders</h1>

# %%
train_data, valid_data = sklearn.model_selection.train_test_split(df, test_size=0.25, shuffle=True)

# %%
class StrokeDataset(torch.utils.data.Dataset):
    def __init__(self, data):
        self.labels = data['stroke']
        self.samples = data.drop(columns=['stroke', 'id', 'split'])

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.samples.iloc[idx], self.labels.iloc[idx]

# %%
train_dataloader = StrokeDataset(train_data)
valid_dataloader = StrokeDataset(valid_data)

# %%
# %%html
# <h3>I think shuffling is a good idea because if we take a look at the pmi-data.csv we can see that all the cases with stroke=1 come first in the csv so that means if we didnt shuffle, all of them would be chosen for the training and none would be left for the testing</h3>
# Out:
# <h3>I think shuffling is a good idea because if we take a look at the pmi-data.csv we can see that all the cases with stroke=1 come first in the csv so that means if we didnt shuffle, all of them would be chosen for the training and none would be left for the testing</h3>

# %%
# %%html
# <h1>2. Model</h1>
# Out:
# <h1>2. Model</h1>

# %%
import torch.nn.functional as F
class Model(torch.nn.Module):
    def __init__(self, in_size, out_size):
        super().__init__()
        self.l1 = torch.nn.Linear(in_features=in_size, out_features=64)
        self.l2 = torch.nn.Linear(in_features=64, out_features=32)
        self.l3 = torch.nn.Linear(in_features=32, out_features=16)
        self.l4 = torch.nn.Linear(in_features=16, out_features=16)
        # self.l5 = torch.nn.Linear(in_features=16, out_features=16)
        # self.l5_6 = torch.nn.Linear(in_features=16, out_features=16)
        self.l6 = torch.nn.Linear(in_features=16, out_features=16)
        self.l7 = torch.nn.Linear(in_features=16, out_features=16)
        self.l8 = torch.nn.Linear(in_features=16, out_features=8)
        self.l9 = torch.nn.Linear(in_features=8, out_features=out_size)

    def forward(self, x):
        x = torch.Tensor(x.values)
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))
        x = F.relu(self.l3(x))
        x = F.relu(self.l4(x))
        # x = F.relu(self.l5(x))
        # x = F.relu(self.l5_6(x))
        x = F.relu(self.l6(x))
        x = F.relu(self.l7(x))
        x = F.relu(self.l8(x))
        x = self.l9(x)
        return x

# %%
model = Model(10, 1)

# %%
# for param in model.parameters():
#     print(param)

# %%
# %%html
# <h1>3. Optimizer and Loss function</h1>
# Out:
# <h1>3. Optimizer and Loss function</h1>

# %%
optimizer = torch.optim.Adam(model.parameters())
loss_fn = torch.nn.BCEWithLogitsLoss()

# %%
# %%html
# <h1>4. Training </h1>
# Out:
# <h1>4. Training </h1>

# %%
N_EPOCHS = 4

best_acc = 0

hist_train_loss = []
hist_valid_loss = []
hist_accuracy = []

for epoch in range(N_EPOCHS):
    train_loss = 0
    valid_loss = 0
    
    for i, data in enumerate(train_dataloader, 0):
        features, labels = data
        
        optimizer.zero_grad()

        outputs = model(features)
        #y_true = torch.tensor(labels).to(torch.float)
        loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

    y_pred = []
    y_true = []
    with torch.no_grad():
        for i, data in enumerate(valid_dataloader, 0):
            features, labels = data
            y_true.append(labels)
            
            outputs = model.forward(features)
            
            loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
            valid_loss += loss.item()
            y_pred.append(torch.sigmoid(outputs) > 0.5)

    accuracy = sklearn.metrics.accuracy_score(y_true, y_pred)
    print(f'Epoch {epoch}, accuracy: {accuracy}, train_loss={train_loss / len(train_dataloader)}, valid_loss={valid_loss / len(valid_dataloader)}')
    if accuracy > best_acc:
        torch.save(model.state_dict(), 'best_unbalanced_accuracy')
        best_acc = accuracy

    hist_train_loss.append(train_loss)
    hist_valid_loss.append(valid_loss)
    hist_accuracy.append(accuracy)
# Out:
# KeyboardInterrupt

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(hist_train_loss, label='Training Loss')
plt.plot(hist_valid_loss, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(hist_accuracy, label='Training Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# %%html
# <h1>5. Evaluation</h1>
# Out:
# <h1>5. Evaluation</h1>

# %%
model.load_state_dict(torch.load('best_unbalanced_accuracy'))
y_true = []
y_pred = []
with torch.no_grad():
    for i, data in enumerate(valid_dataloader, 0):
        features, labels = data
        y_true.append(labels)
        
        outputs = model.forward(features)
        
        loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
        valid_loss += loss.item()
        y_pred.append(torch.sigmoid(outputs) > 0.5)

# %%
conf_matrix = sklearn.metrics.confusion_matrix(y_true, y_pred)
precision = sklearn.metrics.precision_score(y_true, y_pred, zero_division=)
recall = sklearn.metrics.recall_score(y_true, y_pred)
f1_score = sklearn.metrics.f1_score(y_true, y_pred)
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1_score: {f1_score}')
sklearn.metrics.ConfusionMatrixDisplay(conf_matrix).plot()
# Out:
# Precision: 0.0
# Recall: 0.0
# F1_score: 0.0
# C:\Users\Fabi\anaconda3\envs\tema1_rna\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# %%html
# <h1>6. Balance the training data distribution</h1>
# Out:
# <h1>6. Balance the training data distribution</h1>

# %%
model = Model(10, 1)
labels = train_dataloader.labels
pos_weight = torch.tensor(len([x for x in labels if x == 0]) / len([x for x in labels if x == 1]))
optimizer = torch.optim.Adam(model.parameters())
loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# %%
pos_weight
# Out:
# tensor(17.6993)

# %%
N_EPOCHS = 30

best_f1_score = 0

hist_train_loss = []
hist_valid_loss = []

hist_accuracy = []
hist_precision = []
hist_recall = []
hist_f1_score = []

for epoch in range(N_EPOCHS):
    train_loss = 0
    valid_loss = 0
    
    for i, data in enumerate(train_dataloader, 0):
        features, labels = data
        
        optimizer.zero_grad()

        outputs = model(features)
        #y_true = torch.tensor(labels).to(torch.float)
        loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

    y_pred = []
    y_true = []
    with torch.no_grad():
        for i, data in enumerate(valid_dataloader, 0):
            features, labels = data
            y_true.append(labels)
            
            outputs = model.forward(features)
            
            loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
            valid_loss += loss.item()
            y_pred.append(torch.sigmoid(outputs) > 0.5)

    accuracy = sklearn.metrics.accuracy_score(y_true, y_pred)
    f1_score = sklearn.metrics.f1_score(y_true, y_pred, zero_division=0)
    recall = sklearn.metrics.recall_score(y_true, y_pred, zero_division=0)
    precision = sklearn.metrics.precision_score(y_true, y_pred, zero_division=0)

    hist_f1_score.append(f1_score)
    hist_recall.append(recall)
    hist_precision.append(precision)
    
    print(f'Epoch {epoch}, accuracy: {accuracy}, train_loss={train_loss / len(train_dataloader)}, valid_loss={valid_loss / len(valid_dataloader)}, f1_score={f1_score}, recall={recall}, precision={precision}, {"*" if (f1_score > best_f1_score) else None}')
    if f1_score > best_f1_score:
        torch.save(model.state_dict(), 'best_balanced_f1')
        best_f1_score = f1_score

    hist_train_loss.append(train_loss)
    hist_valid_loss.append(valid_loss)
    hist_accuracy.append(accuracy)
# Out:
# Epoch 0, accuracy: 0.827354260089686, train_loss=1.164898859023513, valid_loss=1.0322484679419899, f1_score=0.2376237623762376, recall=0.5581395348837209, precision=0.1509433962264151, *
# Epoch 1, accuracy: 0.6973094170403588, train_loss=1.1996639770920274, valid_loss=0.9832429410430348, f1_score=0.19161676646706588, recall=0.7441860465116279, precision=0.10996563573883161, None
# Epoch 2, accuracy: 0.7858744394618834, train_loss=1.1121456439181236, valid_loss=1.0162284735072353, f1_score=0.200836820083682, recall=0.5581395348837209, precision=0.12244897959183673, None
# Epoch 3, accuracy: 0.7612107623318386, train_loss=1.1715177212108314, valid_loss=1.02071196702831, f1_score=0.2140221402214022, recall=0.6744186046511628, precision=0.12719298245614036, None
# Epoch 4, accuracy: 0.679372197309417, train_loss=1.116108565753578, valid_loss=0.9795502240815505, f1_score=0.1875, recall=0.7674418604651163, precision=0.10679611650485436, None
# Epoch 5, accuracy: 0.7488789237668162, train_loss=1.0580411880383673, valid_loss=1.0124325401780316, f1_score=0.2112676056338028, recall=0.6976744186046512, precision=0.12448132780082988, None
# Epoch 6, accuracy: 0.9517937219730942, train_loss=1.1026741324985927, valid_loss=1.3503604765162873, f1_score=0.0, recall=0.0, precision=0.0, None
# Epoch 7, accuracy: 0.7701793721973094, train_loss=1.1608893371444187, valid_loss=1.0287792208216116, f1_score=0.21455938697318008, recall=0.6511627906976745, precision=0.12844036697247707, None
# Epoch 8, accuracy: 0.8004484304932735, train_loss=1.0426828968007795, valid_loss=0.9731557999357514, f1_score=0.21929824561403508, recall=0.5813953488372093, precision=0.13513513513513514, None
# Epoch 9, accuracy: 0.8060538116591929, train_loss=1.1229884642982269, valid_loss=1.0066093327686392, f1_score=0.2445414847161572, recall=0.6511627906976745, precision=0.15053763440860216, *
# Epoch 10, accuracy: 0.8800448430493274, train_loss=1.0431230107660872, valid_loss=1.1498767201675963, f1_score=0.2074074074074074, recall=0.32558139534883723, precision=0.15217391304347827, None
# Epoch 27, accuracy: 0.6311659192825112, train_loss=1.2342680271048998, valid_loss=0.932816718024256, f1_score=0.18362282878411912, recall=0.8604651162790697, precision=0.10277777777777777, None
# Epoch 28, accuracy: 0.7331838565022422, train_loss=1.5944558834084488, valid_loss=0.9701576613123641, f1_score=0.2119205298013245, recall=0.7441860465116279, precision=0.12355212355212356, None
# Epoch 29, accuracy: 0.7802690582959642, train_loss=1.2580999216662474, valid_loss=0.9452405602007169, f1_score=0.216, recall=0.627906976744186, precision=0.13043478260869565, None

# %%
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(hist_train_loss, label='Training Loss')
plt.plot(hist_valid_loss, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(hist_accuracy, label='Validation accuracy')
plt.plot(hist_f1_score, label='Validation f1_score')
plt.plot(hist_precision, label='Validation precision')
plt.plot(hist_recall, label='Validation recall')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
model.load_state_dict(torch.load('best_balanced_f1'))
y_true = []
y_pred = []
with torch.no_grad():
    for i, data in enumerate(valid_dataloader, 0):
        features, labels = data
        y_true.append(labels)
        
        outputs = model.forward(features)
        
        loss = loss_fn(outputs[0].float(), torch.tensor(labels).float())
        y_pred.append(torch.sigmoid(outputs) > 0.5)
conf_matrix = sklearn.metrics.confusion_matrix(y_true, y_pred)
precision = sklearn.metrics.precision_score(y_true, y_pred, zero_division=0)
recall = sklearn.metrics.recall_score(y_true, y_pred)
f1_score = sklearn.metrics.f1_score(y_true, y_pred)
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1_score: {f1_score}')
sklearn.metrics.ConfusionMatrixDisplay(conf_matrix).plot()
# Out:
# Precision: 0.15104166666666666
# Recall: 0.6744186046511628
# F1_score: 0.24680851063829787

# %%
# %%html
# <h1>7. Focal Loss</h1>
# Out:
# <h1>7. Focal Loss</h1>

# %%
# Out:
# 'torch'

# %%
model = Model(10, 1)
labels = train_dataloader.labels
optimizer = torch.optim.Adam(model.parameters())
loss_fn = keras.losses.BinaryFocalCrossentropy(alpha=0.7, gamma=2, from_logits=True)

# %%
N_EPOCHS = 30

best_f1_score = 0

hist_train_loss = []
hist_valid_loss = []

hist_accuracy = []
hist_precision = []
hist_recall = []
hist_f1_score = []

for epoch in range(N_EPOCHS):
    train_loss = 0
    valid_loss = 0
    
    for i, data in enumerate(train_dataloader, 0):
        features, labels = data
        
        optimizer.zero_grad()

        outputs = model(features)
        #y_true = torch.tensor(labels).to(torch.float)
        print(outputs[0])
        loss = loss_fn(outputs, torch.tensor(labels).float())
        train_loss += loss
        loss.backward()
        optimizer.step()

    y_pred = []
    y_true = []
    with torch.no_grad():
        for i, data in enumerate(valid_dataloader, 0):
            features, labels = data
            y_true.append(labels)
            
            outputs = model.forward(features)
            
            loss = loss_fn(outputs, torch.tensor(labels).float())
            valid_loss += loss.item()
            y_pred.append(torch.sigmoid(outputs) > 0.5)

    accuracy = sklearn.metrics.accuracy_score(y_true, y_pred)
    f1_score = sklearn.metrics.f1_score(y_true, y_pred, zero_division=0)
    recall = sklearn.metrics.recall_score(y_true, y_pred, zero_division=0)
    precision = sklearn.metrics.precision_score(y_true, y_pred, zero_division=0)

    hist_f1_score.append(f1_score)
    hist_recall.append(recall)
    hist_precision.append(precision)
    
    print(f'Epoch {epoch}, accuracy: {accuracy}, train_loss={train_loss / len(train_dataloader)}, valid_loss={valid_loss / len(valid_dataloader)}, f1_score={f1_score}, recall={recall}, precision={precision}, {"*" if (f1_score > best_f1_score) else None}')
    if f1_score > best_f1_score:
        torch.save(model.state_dict(), 'best_balanced_f1')
        best_f1_score = f1_score

    hist_train_loss.append(train_loss)
    hist_valid_loss.append(valid_loss)
    hist_accuracy.append(accuracy)
# Out:
# tensor(0.1594, grad_fn=<SelectBackward0>)
# tensor(0.1585, grad_fn=<SelectBackward0>)
# tensor(0.1583, grad_fn=<SelectBackward0>)
# tensor(0.1595, grad_fn=<SelectBackward0>)
# tensor(0.1608, grad_fn=<SelectBackward0>)
# tensor(0.1552, grad_fn=<SelectBackward0>)
# tensor(0.1609, grad_fn=<SelectBackward0>)
# tensor(0.1593, grad_fn=<SelectBackward0>)
# tensor(0.1533, grad_fn=<SelectBackward0>)
# tensor(0.1625, grad_fn=<SelectBackward0>)
# tensor(0.1571, grad_fn=<SelectBackward0>)
# tensor(0.1594, grad_fn=<SelectBackward0>)
# tensor(0.1579, grad_fn=<SelectBackward0>)
# tensor(0.1552, grad_fn=<SelectBackward0>)
# tensor(0.1611, grad_fn=<SelectBackward0>)
# tensor(0.1536, grad_fn=<SelectBackward0>)
# tensor(0.1582, grad_fn=<SelectBackward0>)
# tensor(0.1629, grad_fn=<SelectBackward0>)
# tensor(0.1556, grad_fn=<SelectBackward0>)
# tensor(0.1588, grad_fn=<SelectBackward0>)
# tensor(0.1606, grad_fn=<SelectBackward0>)
# tensor(0.1418, grad_fn=<SelectBackward0>)
# tensor(0.1619, grad_fn=<SelectBackward0>)
# tensor(0.1369, grad_fn=<SelectBackward0>)
# tensor(0.1573, grad_fn=<SelectBackward0>)
# tensor(0.1612, grad_fn=<SelectBackward0>)
# tensor(0.1618, grad_fn=<SelectBackward0>)
# tensor(0.1571, grad_fn=<SelectBackward0>)
# tensor(0.1604, grad_fn=<SelectBackward0>)
# tensor(0.1570, grad_fn=<SelectBackward0>)
# tensor(0.1638, grad_fn=<SelectBackward0>)
# tensor(0.1562, grad_fn=<SelectBackward0>)
# tensor(0.1619, grad_fn=<SelectBackward0>)
# tensor(0.1599, grad_fn=<SelectBackward0>)
# tensor(0.1646, grad_fn=<SelectBackward0>)
# tensor(0.1589, grad_fn=<SelectBackward0>)
# tensor(0.1565, grad_fn=<SelectBackward0>)
# tensor(0.1610, grad_fn=<SelectBackward0>)
# tensor(0.1550, grad_fn=<SelectBackward0>)
# tensor(0.1562, grad_fn=<SelectBackward0>)
# tensor(0.1641, grad_fn=<SelectBackward0>)
# tensor(0.1577, grad_fn=<SelectBackward0>)
# tensor(0.1605, grad_fn=<SelectBackward0>)
# tensor(0.2997, grad_fn=<SelectBackward0>)
# tensor(0.3122, grad_fn=<SelectBackward0>)
# tensor(0.3565, grad_fn=<SelectBackward0>)
# tensor(0.3322, grad_fn=<SelectBackward0>)
# tensor(0.3662, grad_fn=<SelectBackward0>)
# tensor(0.3335, grad_fn=<SelectBackward0>)
# tensor(0.3467, grad_fn=<SelectBackward0>)
# tensor(0.3413, grad_fn=<SelectBackward0>)
# tensor(0.3615, grad_fn=<SelectBackward0>)
# tensor(0.3662, grad_fn=<SelectBackward0>)
# tensor(0.3643, grad_fn=<SelectBackward0>)
# tensor(0.4595, grad_fn=<SelectBackward0>)
# tensor(0.3917, grad_fn=<SelectBackward0>)
# tensor(0.3852, grad_fn=<SelectBackward0>)
# tensor(0.4689, grad_fn=<SelectBackward0>)
# tensor(0.3917, grad_fn=<SelectBackward0>)
# tensor(0.3802, grad_fn=<SelectBackward0>)
# tensor(0.3863, grad_fn=<SelectBackward0>)
# tensor(0.3650, grad_fn=<SelectBackward0>)
# tensor(0.3941, grad_fn=<SelectBackward0>)
# tensor(0.4275, grad_fn=<SelectBackward0>)
# tensor(0.4783, grad_fn=<SelectBackward0>)
# tensor(0.3911, grad_fn=<SelectBackward0>)
# tensor(0.3958, grad_fn=<SelectBackward0>)
# tensor(0.4006, grad_fn=<SelectBackward0>)
# tensor(0.4144, grad_fn=<SelectBackward0>)
# tensor(0.4373, grad_fn=<SelectBackward0>)
# tensor(0.4019, grad_fn=<SelectBackward0>)
# tensor(0.4497, grad_fn=<SelectBackward0>)
# tensor(0.4641, grad_fn=<SelectBackward0>)
# tensor(0.4634, grad_fn=<SelectBackward0>)
# tensor(0.4917, grad_fn=<SelectBackward0>)
# tensor(0.4495, grad_fn=<SelectBackward0>)
# tensor(0.4895, grad_fn=<SelectBackward0>)
# tensor(0.4747, grad_fn=<SelectBackward0>)
# tensor(0.5138, grad_fn=<SelectBackward0>)
# tensor(0.4895, grad_fn=<SelectBackward0>)
# tensor(0.4795, grad_fn=<SelectBackward0>)
# tensor(0.4485, grad_fn=<SelectBackward0>)
# tensor(0.7310, grad_fn=<SelectBackward0>)
# tensor(0.5403, grad_fn=<SelectBackward0>)
# tensor(0.5516, grad_fn=<SelectBackward0>)
# tensor(0.6112, grad_fn=<SelectBackward0>)
# tensor(0.5953, grad_fn=<SelectBackward0>)
# tensor(0.5406, grad_fn=<SelectBackward0>)
# tensor(0.5802, grad_fn=<SelectBackward0>)
# tensor(0.5532, grad_fn=<SelectBackward0>)
# tensor(0.5485, grad_fn=<SelectBackward0>)
# tensor(0.5937, grad_fn=<SelectBackward0>)
# tensor(0.5369, grad_fn=<SelectBackward0>)
# tensor(0.6212, grad_fn=<SelectBackward0>)
# tensor(0.6323, grad_fn=<SelectBackward0>)
# tensor(0.5961, grad_fn=<SelectBackward0>)
# tensor(0.5576, grad_fn=<SelectBackward0>)
# tensor(0.5885, grad_fn=<SelectBackward0>)
# tensor(0.6102, grad_fn=<SelectBackward0>)
# tensor(0.6823, grad_fn=<SelectBackward0>)
# tensor(0.6392, grad_fn=<SelectBackward0>)
# tensor(0.7477, grad_fn=<SelectBackward0>)
# tensor(0.6664, grad_fn=<SelectBackward0>)
# tensor(0.6232, grad_fn=<SelectBackward0>)
# tensor(0.6891, grad_fn=<SelectBackward0>)
# tensor(0.6983, grad_fn=<SelectBackward0>)
# tensor(0.9685, grad_fn=<SelectBackward0>)
# tensor(1.0011, grad_fn=<SelectBackward0>)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 25
#      23 #y_true = torch.tensor(labels).to(torch.float)
#      24 print(outputs[0])
# ---> 25 loss = loss_fn(outputs, torch.tensor(labels).float())
#      26 train_loss += loss
#      27 loss.backward()
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\losses\loss.py:67, in Loss.__call__(self, y_true, y_pred, sample_weight)
#      60 y_pred = tree.map_structure(
#      61     lambda x: ops.convert_to_tensor(x, dtype=self.dtype), y_pred
#      62 )
#      63 y_true = tree.map_structure(
#      64     lambda x: ops.convert_to_tensor(x, dtype=self.dtype), y_true
#      65 )
# ---> 67 losses = self.call(y_true, y_pred)
#      68 out_mask = backend.get_keras_mask(losses)
#      70 if in_mask is not None and out_mask is not None:
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\losses\losses.py:33, in LossFunctionWrapper.call(self, y_true, y_pred)
#      31 y_true = tree.map_structure_up_to(y_true, lambda x: x[0], y_true_y_pred)
#      32 y_pred = tree.map_structure_up_to(y_pred, lambda x: x[1], y_true_y_pred)
# ---> 33 return self.fn(y_true, y_pred, **self._fn_kwargs)
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\losses\losses.py:2389, in binary_focal_crossentropy(y_true, y_pred, apply_class_balancing, alpha, gamma, from_logits, label_smoothing, axis)
#    2387 # Calculate focal factor
#    2388 p_t = y_true * y_pred + (1 - y_true) * (1 - y_pred)
# -> 2389 focal_factor = ops.power(1.0 - p_t, gamma)
#    2391 focal_bce = focal_factor * bce
#    2393 if apply_class_balancing:
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\ops\numpy.py:6252, in power(x1, x2)
#    6250 if any_symbolic_tensors((x1, x2)):
#    6251     return Power().symbolic_call(x1, x2)
# -> 6252 return backend.numpy.power(x1, x2)
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\backend\torch\numpy.py:1601, in power(x1, x2)
#    1600 def power(x1, x2):
# -> 1601     x1, x2 = convert_to_tensor(x1), convert_to_tensor(x2)
#    1602     return torch.pow(x1, x2)
#
# File ~\anaconda3\envs\tema1_rna\lib\site-packages\keras\src\backend\torch\core.py:210, in convert_to_tensor(x, dtype, sparse, ragged)
#     208     return torch.as_tensor(x, dtype=torch.bool, device=get_device())
#     209 elif isinstance(x, int):
# --> 210     return torch.as_tensor(x, dtype=torch.int32, device=get_device())
#     211 elif isinstance(x, float):
#     212     return torch.as_tensor(
#     213         x, dtype=to_torch_dtype(floatx()), device=get_device()
#     214     )
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
