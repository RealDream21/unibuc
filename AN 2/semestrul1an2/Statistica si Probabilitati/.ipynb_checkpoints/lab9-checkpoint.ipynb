# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt

expon = scipy.stats.expon

lam = 1
scale = 1/lam

# %%
simulari = expon.rvs(scale=scale, size= 1000) #rvs = random variates

plt.hist(simulari)
# Out:
# (array([507., 240., 127.,  66.,  21.,  22.,   8.,   2.,   6.,   1.]),
#  array([1.17534605e-03, 7.15756442e-01, 1.43033754e+00, 2.14491863e+00,
#         2.85949973e+00, 3.57408083e+00, 4.28866192e+00, 5.00324302e+00,
#         5.71782412e+00, 6.43240521e+00, 7.14698631e+00]),
#  <BarContainer object of 10 artists>)
